# %%
import yaml
import pandas
import pathlib
import googleapiclient.discovery
import googleapiclient.errors

# %%
api_key = yaml.safe_load(open(f"{pathlib.Path().absolute().parent.as_posix()}/secrets.yaml"))['api_key']

# %%
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# %%
url = "https://www.youtube.com/watch?v=wen1BmMaShQ"

request = youtube.videos().list(
    part="snippet,statistics,contentDetails",
    id=url.split('=')[-1]
)
response = request.execute()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 url = "https://www.youtube.com/watch?v=wen1BmMaShQ"
# ----> 3 request = youtube.videos().list(
#       4     part="snippet,statistics,contentDetails",
#       5     id=url.split('=')[-1]
#       6 )
#       7 response = request.execute()
#
# NameError: name 'youtube' is not defined

# %%
published_time = response['items'][0]['snippet']['publishedAt']
video_title = response['items'][0]['snippet']['title']
video_description = response['items'][0]['snippet']['description']
video_views = response['items'][0]['statistics']['viewCount']
video_likes = response['items'][0]['statistics']['likeCount']
video_comments = response['items'][0]['statistics']['commentCount']
video_duration = response['items'][0]['contentDetails']['duration']

print(f"Title: {video_title}")
print(f"Published Timing: {published_time}")
# print(f"Description: {video_description}")
print(f"Views: {video_views}")
print(f"Likes: {video_likes}")
print(f"Duration: {video_duration}")
print(f"Total Comments: {video_comments}")

# %%
request = youtube.commentThreads().list(
            part="snippet",
            videoId='lWx7VDYN2jI',
            maxResults=100,
            # pageToken=next_page_token
          )
response = request.execute()
response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'LFJOoo2_N1wM7bDDvwTZinxPjG0',
#  'pageInfo': {'totalResults': 27, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'DckjdFkBRQtkJDXasn2aZJ9HiQw',
#    'id': 'UgzdlAW-8AiWGg53Bmx4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'PikOB9FCPuMYm6sbN0yy2a_wK5c',
#      'id': 'UgzdlAW-8AiWGg53Bmx4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'Aapki agarbatti😂😂😂😂😂',
#       'textOriginal': 'Aapki agarbatti😂😂😂😂😂',
#       'authorDisplayName': '@ankuraggarwal4481',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lxnRKkgHmhBQpuj_5NFIvDYaPyUvdVLQPIr5Vzi4Hd4-M=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ankuraggarwal4481',
#       'authorChannelId': {'value': 'UCs5OEs7hRyZ0ybAl_qzkwLA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-09-29T07:47:03Z',
#       'updatedAt': '2024-09-29T07:47:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'jtsdrCX3juNFHAxpHj6K296y9TY',
#    'id': 'Ugyw8VQRpFbwkIaPSg54AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'pw5g6jdcVr2hEEB8hJo2k8ooD_0',
#      'id': 'Ugyw8VQRpFbwkIaPSg54AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'Ye video title padhna ke baar😊😊',
#       'textOriginal': 'Ye video title padhna ke baar😊😊',
#       'authorDisplayName': '@lalanchoudhary2849',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l7I9Z2ruLwb_8O5wqZX3BeggKDhG9XW1jritguKKq0ERDMHNocJbKZGdEYuVaEVLicvQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@lalanchoudhary2849',
#       'authorChannelId': {'value': 'UCy_UhT1xhRjWcXKL_PkbBbA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-09-10T11:07:07Z',
#       'updatedAt': '2024-09-10T11:07:07Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'lbQSukh_LDQXqPimUXeSnWnrr2I',
#    'id': 'Ugzc8dzTHg7YGWnKWyZ4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Q2X_r8b1vGbvd1lf-vjsyAFZG38',
#      'id': 'Ugzc8dzTHg7YGWnKWyZ4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=lWx7VDYN2jI&amp;t=24">0:24</a>tap ♾️😅',
#       'textOriginal': '0:24tap ♾️😅',
#       'authorDisplayName': '@iam__roshan07',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com
=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ankursharma7812',
#       'authorChannelId': {'value': 'UCYrOhIReEtA9alaIF7UGSxA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 8,
#       'publishedAt': '2024-04-11T04:16:24Z',
#       'updatedAt': '2024-04-11T04:16:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'qB2UAFaoBpk5XsLYywwr2riuKj0',
#    'id': 'UgzgxduBvU_hVKFApWd4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'YuVkWE0OqxkoNfTGpeP-9HjcAdk',
#      'id': 'UgzgxduBvU_hVKFApWd4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'Kaun bata sakta hai anupam, aman, and peyush me kiske kiske hair nakli hai',
#       'textOriginal': 'Kaun bata sakta hai anupam, aman, and peyush me kiske kiske hair nakli hai',
#       'authorDisplayName': '@technicalworld1361',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mUbLwVqf1Ur4iTjPvLf9C0-5Ikl28st_lTTyLuL6krrFg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@technicalworld1361',
#       'authorChannelId': {'value': 'UCGKt5Tf-cxdz8iH3JoEprSw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-10T09:30:22Z',
#       'updatedAt': '2024-04-10T09:30:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'hutkzMM2qntxjnSGMKYvbUFkcH0',
#    'id': 'Ugx_tqN1pE9VXJ18Ui14AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '8HdHbH5wd6zVVn-WNQw6N5HCFU0',
#      'id': 'Ugx_tqN1pE9VXJ18Ui14AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'My favourite shark Aman Gupta 😊',
#       'textOriginal': 'My favourite shark Aman Gupta 😊',
#       'authorDisplayName': '@Muskan-x3c2o',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lkd0rxDNf5fMK_UoPYRhOsgwNtwY9ZOs1KY-dpA5QhVhAqxMEwBKhHbjPdHHUvhecsUw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Muskan-x3c2o',
#       'authorChannelId': {'value': 'UCkgj5qbN6CvO_5dned8uZEw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2024-04-03T17:07:46Z',
#       'updatedAt': '2024-04-03T17:07:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 't7NJWYoLE_PpMVPDPi9umwu3XdM',
#    'id': 'UgzKP90YfbSwBNhZp_p4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'M-ekttzwz0OQv7KIOMNhrhpWIhU',
#      'id': 'UgzKP90YfbSwBNhZp_p4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=lWx7VDYN2jI&amp;t=206">3:26</a> his leg is OUT. Decision made',
#       'textOriginal': '3:26 his leg is OUT. Decision made',
#       'authorDisplayName': '@niharikakurma6937',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kAUnGERD__14gx77EQ9oI2nS0NW5G3mwVu6z-d26Y=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@niharikakurma6937',
#       'authorChannelId': {'value': 'UCgPxROKH3zzWTn_zJv1GLPg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 8,
#       'publishedAt': '2024-03-27T10:54:58Z',
#       'updatedAt': '2024-03-27T10:54:58Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'aKWpcTDumEtdVfDR-5wBVj0ng2c',
#    'id': 'UgxO6ZshgeUAZrTxvyt4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'bk3RZphHBy0NTQfQTBxq76ekKfM',
#      'id': 'UgxO6ZshgeUAZrTxvyt4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=lWx7VDYN2jI&amp;t=216">3:36</a> &quot;pataaa&quot; by aman🤣',
#       'textOriginal': '3:36 "pataaa" by aman🤣',
#       'authorDisplayName': '@niharikakurma6937',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kAUnGERD__14gx77EQ9oI2nS0NW5G3mwVu6z-d26Y=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@niharikakurma6937',
#       'authorChannelId': {'value': 'UCgPxROKH3zzWTn_zJv1GLPg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 13,
#       'publishedAt': '2024-03-27T10:41:06Z',
#       'updatedAt': '2024-03-27T10:41:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5VwbfDd7ThS1R2KPl8dFHZnuho0',
#    'id': 'UgxlWHGd7E6HwOIwu5J4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2tP2a1E1COMKg84WbKc2CU3qhhU',
#      'id': 'UgxlWHGd7E6HwOIwu5J4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'We will get in thirupati also',
#       'textOriginal': 'We will get in thirupati also',
#       'authorDisplayName': '@AnchuriCreats',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/7KkwVDUlpctlz5YOKwTffIDvdP6eUhfM9qqWQYp9iqvFirfyxFyzUMoh4dwHpjWwuG5DuIRBmg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@AnchuriCreats',
#       'authorChannelId': {'value': 'UCmMP9Lc01UafDyid00ECz2g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-03-25T15:51:53Z',
#       'updatedAt': '2024-03-25T15:51:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ANhEEF1xFZOPxRiuj7Figk0wiuY',
#    'id': 'UgzF4_WX04zxH2topOd4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ssrks7gs9r2NyxB1H2RmrYGxwjo',
#      'id': 'UgzF4_WX04zxH2topOd4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'Aman ki lagta h Damani ne mar rakhi hai',
#       'textOriginal': 'Aman ki lagta h Damani ne mar rakhi hai',
#       'authorDisplayName': '@vineetgupta4391',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lBwYgTxeekaNd8Wor2GJSlz45N0Hl7RIhKFF_z90oXXAA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@vineetgupta4391',
#       'authorChannelId': {'value': 'UC7ZbNpWpEFOuCVhkERDqnPA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-03-25T14:37:21Z',
#       'updatedAt': '2024-03-25T14:37:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'd5xsEnuE9v18gXw-jWvIHpdniDE',
#    'id': 'UgyApSc9MUgsBhcoHSV4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-Yhc88zEGg7UvoumHvBsZzIn2L8',
#      'id': 'UgyApSc9MUgsBhcoHSV4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'Clickbait. Title mein Investment ki race likh diya but saare sharks out. Wtf',
#       'textOriginal': 'Clickbait. Title mein Investment ki race likh diya but saare sharks out. Wtf',
#       'authorDisplayName': '@rookietheone',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mbSGjjgKvbD0lnj8yaBBnGVaNghLTm5HUJ01q5c-gTIx5d=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@rookietheone',
#       'authorChannelId': {'value': 'UCQ_u4BTI8mAqtHunGgg3GZQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 58,
#       'publishedAt': '2024-03-25T12:11:26Z',
#       'updatedAt': '2024-03-25T12:12:42Z'}},
#     'canReply': True,
#     'totalReplyCount': 3,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LS8ydyv-4Z0F-85YJd9LJ3cEDeg',
#    'id': 'Ugxz8xefk5n9uovdu5Z4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gfAa3WQ9bHfrkjpXhGwpXOQKcY8',
#      'id': 'Ugxz8xefk5n9uovdu5Z4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'Kaha bhai “investment ki race”… ?<br>Sony liv youtube handle should get some funding for good marketing skills.',
#       'textOriginal': 'Kaha bhai “investment ki race”… ?\nSony liv youtube handle should get some funding for good marketing skills.',
#       'authorDisplayName': '@amoghprabhudesai6874',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nqsKpmQokt8mZb2IDrPY3ZqBYG71BhnNlHDaZAtbG3KDw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@amoghprabhudesai6874',
#       'authorChannelId': {'value': 'UCwAlc8muROolWp-Sf3rY5RA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 14,
#       'publishedAt': '2024-03-25T09:57:06Z',
#       'updatedAt': '2024-03-25T09:57:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'PxFUns-pI_OB0D2esstGAqrT2NE',
#    'id': 'Ugz1xfLA2DxBArqYnFx4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'icpBoPHqLldLK16-VVK2P7F0MIY',
#      'id': 'Ugz1xfLA2DxBArqYnFx4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=lWx7VDYN2jI&amp;t=482">8:02</a> Abe yeh kya tha 😮',
#       'textOriginal': '8:02 Abe yeh kya tha 😮',
#       'authorDisplayName': '@AtulkumarVerma-p5f',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/94QO0rjhIsEcOxtBbwk7E08J1_eb_8RiDaj-zLjbDzGQ5VIMBn1GCH_0Dr2JZX1AakoWdFxpFQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@AtulkumarVerma-p5f',
#       'authorChannelId': {'value': 'UCnb3uxnEPqeLRidET6cSVbA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 10,
#       'publishedAt': '2024-03-25T09:56:36Z',
#       'updatedAt': '2024-03-25T09:56:36Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '1-fOyqaNj5qqFJfDBszUL19W3pk',
#    'id': 'UgwdfeCm3aEzRRw-Iy94AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'z3Bz8UPQjuIFHqaNW_Z7LCsaVJc',
#      'id': 'UgwdfeCm3aEzRRw-Iy94AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': '<b>investment ki race kidhar hai admin</b>',
#       'textOriginal': '*investment ki race kidhar hai admin*',
#       'authorDisplayName': '@deepaklahari5778',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m2UUj5c4ik9gfF4l0CSUMQ1PykrU-C7DbUj40UOEJw6sc=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@deepaklahari5778',
#       'authorChannelId': {'value': 'UCwJh2ddfHVPkNFkLWzZ_3yw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 83,
#       'publishedAt': '2024-03-25T08:46:09Z',
#       'updatedAt': '2024-03-25T08:46:09Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ss-5J09SE6ncPHnMX85gVYfNXdg',
#    'id': 'Ugz6nY2ydN4FfNI4yNd4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ae4PPB11xEAmtM1KPlY9aOy-KnA',
#      'id': 'Ugz6nY2ydN4FfNI4yNd4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'So irritating when these Shark specially anupam fake khasi ki acting karta he valuation sun ke 😂😣',
#       'textOriginal': 'So irritating when these Shark specially anupam fake khasi ki acting karta he valuation sun ke 😂😣',
#       'authorDisplayName': '@money3707',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ikkdv8dAIX3I64UXbGvDIF3LgXIeO8KDemGNBCjjaFBs0D5asWyoRh8IY0wtwXQ_Lx7ysQHXCyM=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@money3707',
#       'authorChannelId': {'value': 'UCZpOit7bKkZajdMVtbIYjEw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 240,
#       'publishedAt': '2024-03-25T08:29:19Z',
#       'updatedAt': '2024-03-25T08:29:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 12,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '9Y8x21ThaYmPrTe0FzPKlk19A_k',
#    'id': 'Ugyfz6w-MKiMxK9h-PN4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'LAzD70ycI_aE7NqGTu7q-vWM858',
#      'id': 'Ugyfz6w-MKiMxK9h-PN4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'Aman ka reaction aisa hota hai ki, bhai kuch naya bol diya tune fir se bta to😂😂😅',
#       'textOriginal': 'Aman ka reaction aisa hota hai ki, bhai kuch naya bol diya tune fir se bta to😂😂😅',
#       'authorDisplayName': '@_IamHarsh',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nAKajeoAWEgNQed9H_F70ZjU6faPh-PQNXJHR3Q6M5Du4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@_IamHarsh',
#       'authorChannelId': {'value': 'UC8OvYnbDwSKPbLoYstHaLPA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 10,
#       'publishedAt': '2024-03-25T07:29:33Z',
#       'updatedAt': '2024-03-25T07:29:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xmjInj6f7eEoyG6FS1XKZpThLgI',
#    'id': 'UgwQPxMtAGGdekRWnJR4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'BGdGZxBsnODRMX2HOeveZ13tIDg',
#      'id': 'UgwQPxMtAGGdekRWnJR4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'Itc mangaldeep rules in this incense stick domain. And they didn&#39;t even mentioned about ITC here.',
#       'textOriginal': "Itc mangaldeep rules in this incense stick domain. And they didn't even mentioned about ITC here.",
#       'authorDisplayName': '@priyanshuadhikari5110',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/efmefugyOK6XsqWGzfDW0RY1HxfVgy6kvsyFfLmiTSb4A0souSIEAP6Qy2jFcvkZyxcr-VJfYm4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@priyanshuadhikari5110',
#       'authorChannelId': {'value': 'UCabbmolrzNCy3EAeHM3IPBQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 13,
#       'publishedAt': '2024-03-25T06:11:35Z',
#       'updatedAt': '2024-03-25T06:11:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nGWY3nH-40P7DLiE7vT79mT8MoQ',
#    'id': 'UgybixWROVxi7pnf5bB4AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'wfZ3k251ZczGDmsjvkTCm5O-2-A',
#      'id': 'UgybixWROVxi7pnf5bB4AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'Kaun hain ye sab log jo sabko judge kar rahe hain??? One of the worst show with trash content..',
#       'textOriginal': 'Kaun hain ye sab log jo sabko judge kar rahe hain??? One of the worst show with trash content..',
#       'authorDisplayName': '@rickypats136',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_miTGRejuncZKh3ugN3vcrf0VfLLLnnDF5DALulkS-S1pI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@rickypats136',
#       'authorChannelId': {'value': 'UCdwUsWgDAv7SsH4SugfAoPA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 9,
#       'publishedAt': '2024-03-24T13:39:11Z',
#       'updatedAt': '2024-03-24T13:39:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 5,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'F7p-fVslBJuWWx9wfP4_ygigWw8',
#    'id': 'UgxsXpJWJA-11lnxty54AaABAg',
#    'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#     'videoId': 'lWx7VDYN2jI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-21Ql8fcE3e2bcB6SF-4Eldewkg',
#      'id': 'UgxsXpJWJA-11lnxty54AaABAg',
#      'snippet': {'channelId': 'UCOQNJjhXwvAScuELTT_i7cQ',
#       'videoId': 'lWx7VDYN2jI',
#       'textDisplay': 'Kay kar sakte hai',
#       'textOriginal': 'Kay kar sakte hai',
#       'authorDisplayName': '@GyanSingh-tz1ol',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Z2GTHr0kdy5aTRcVO8Q0bhueZClNstV_BaNyYYAB54U7PtXdXWCVMFhq-RmHWr8VFksXc-2zV4U=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@GyanSingh-tz1ol',
#       'authorChannelId': {'value': 'UCUIURyyXdFgfdv_O1d88z1A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 5,
#       'publishedAt': '2024-03-24T13:06:22Z',
#       'updatedAt': '2024-03-24T13:06:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
url = "https://www.youtube.com/watch?v=A_BF-avmAbk"
videoId = url.split('=')[-1]

youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

def get_comments(videoId):
    comments = []
    next_page_token = None

    while True:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=videoId,
            maxResults=100,
            pageToken=next_page_token
        )
        response = request.execute()

        for item in response['items']:
            top_level_comment = item['snippet']['topLevelComment']['snippet']['textOriginal']
            # total_reply_count = item['snippet']['totalReplyCount']
            # likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']
            comments.append(top_level_comment)

        if 'nextPageToken' not in response:
            break
        next_page_token = response['nextPageToken']
        
        if len(comments) > 25000 : 
            break

    return comments

comments = get_comments(videoId)

import pathlib
import pandas as pd

curr_dir = pathlib.Path().absolute()
home_dir = curr_dir.parent.as_posix()
df = pd.DataFrame(comments, columns=['comment'])
df.to_csv(f"{home_dir}/data/2Oct24_file36.csv", index=False)

# %%
import pandas as pd
import glob
import pathlib

# %%
df = pd.read_csv(r"c:\Users\lenovo\Desktop\youtube-api-testing\data\2Oct24_file16.csv", header=0)
df
# Out:
#                                                  comment
# 0      Link to Dhruv Rathee Academy courses: https://...
# 1                                            Nice sir ji
# 2              Dhruv rathi ji jindabad jindabad jindabad
# 3                   every indians have to see this video
# 4                     Dhruv rathe  tiger 56 inchka sinaa
# ...                                                  ...
# 12095                                                🇵🇰❤
# 12096  Dhruv Rathee sir mai already aap ka bohot bada...
# 12097                                                 Hy
# 12098                          4th pillar of democracy 🤡
# 12099  Modi tumhare jese logo ko bharat me nhi hona c...
#
# [12100 rows x 1 columns]

# %%
# Specify folder path and file extension
folder_path = pathlib.Path(f"{pathlib.Path().absolute().parent.as_posix()}/data/")
file_extension = '*.csv'

# Initialize empty DataFrame
combined_data = pd.DataFrame()

# Loop through Excel files
for file in folder_path.glob('*.csv'):
    # Read Excel file, skipping first row (header)
    df = pd.read_csv(file, header=0)
    
    # Append data to combined DataFrame
    combined_data = pd.concat([combined_data, df])
    
print('total files: ', i)
# Write combined data to new Excel file
combined_data.to_csv('combined_data.csv', index=False)
# Out:
# total files:  0
